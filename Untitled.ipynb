# %%
import numpy as np
import pandas as pd
from scipy import optimize
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from linearmodels.iv import IV2SLS
import pymc3 as pm
import arviz as az
import seaborn as sn
import eurostat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       6 import matplotlib.pyplot as plt
#       7 from linearmodels.iv import IV2SLS
# ----> 8 import pymc3 as pm
#       9 import arviz as az
#      10 import seaborn as sn
#
# ModuleNotFoundError: No module named 'pymc3'

# %%
y_values = [1,1,2,2,3,14]
n_values = [1,2,3,4,5,20]
posterior_list = []
for i in range(len(n_values)):
    with pm.Model() as binomial:
      p = pm.Uniform('p',0,1)
      y = pm.Binomial('y', p = p, observed = y_values[i], n = n_values[i])
      trace = pm.sample(tune=2000)
    print(i)
    posterior = az.from_pymc3(trace)
    posterior_list.append(posterior.posterior.p.values.flatten())
# Out:
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Cast{float64}(2)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1914, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1074, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1138, in constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 131, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 96, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1200, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1120, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1644, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1240, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2649, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver2 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver2 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/numpy/core/include -I/home/nrobledo/.pyenv/versions/3.11.0/include/python3.11 -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/c_code -L/home/nrobledo/.pyenv/versions/3.11.0/lib -fvisibility=hidden -o /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmplmqevycy/maf7dfc2b98019ae231490759913de9c7eae2cf26062201cb60a34079dffa7f98.so /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmplmqevycy/mod.cpp -lpython3.11
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(pythonrun.o): warning: relocation against `_Py_UnhandledKeyboardInterrupt' in read-only section `.text'
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(longobject.o): relocation R_X86_64_PC32 against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC
# /usr/bin/ld: final link failed: bad value
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_s8gfsbsn
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Cast{float64}(2)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1914, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1074, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1138, in constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 131, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 96, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1200, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1120, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1644, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1240, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2649, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver2 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver2 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/numpy/core/include -I/home/nrobledo/.pyenv/versions/3.11.0/include/python3.11 -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/c_code -L/home/nrobledo/.pyenv/versions/3.11.0/lib -fvisibility=hidden -o /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmpmnkgfrtz/maf7dfc2b98019ae231490759913de9c7eae2cf26062201cb60a34079dffa7f98.so /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmpmnkgfrtz/mod.cpp -lpython3.11
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(pythonrun.o): warning: relocation against `_Py_UnhandledKeyboardInterrupt' in read-only section `.text'
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(longobject.o): relocation R_X86_64_PC32 against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC
# /usr/bin/ld: final link failed: bad value
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_b0bzu6dn
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Cast{float64}(2)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1914, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1074, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1138, in constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 131, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/op.py", line 96, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1200, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1120, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1644, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1240, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2649, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver2 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver2 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/numpy/core/include -I/home/nrobledo/.pyenv/versions/3.11.0/include/python3.11 -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/c_code -L/home/nrobledo/.pyenv/versions/3.11.0/lib -fvisibility=hidden -o /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmp96w2xu2k/maf7dfc2b98019ae231490759913de9c7eae2cf26062201cb60a34079dffa7f98.so /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/tmp96w2xu2k/mod.cpp -lpython3.11
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(pythonrun.o): warning: relocation against `_Py_UnhandledKeyboardInterrupt' in read-only section `.text'
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(longobject.o): relocation R_X86_64_PC32 against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC
# /usr/bin/ld: final link failed: bad value
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_o40vb5se
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_746_js7j
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/lazylinker_c.py:79
#      78         if version != actual_version:
# ---> 79             raise ImportError(
#      80                 "Version check of the existing lazylinker compiled file."
#      81                 f" Looking for version {version}, but found {actual_version}. "
#      82                 f"Extra debug information: force_compile={force_compile}, _need_reload={_need_reload}"
#      83             )
#      84 except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.212, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/lazylinker_c.py:100
#      99     if version != actual_version:
# --> 100         raise ImportError(
#     101             "Version check of the existing lazylinker compiled file."
#     102             f" Looking for version {version}, but found {actual_version}. "
#     103             f"Extra debug information: force_compile={force_compile}, _need_reload={_need_reload}"
#     104         )
#     105 except ImportError:
#     106     # It is useless to try to compile if there isn't any
#     107     # compiler!  But we still want to try to load it, in case
#     108     # the cache was copied from another computer.
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.212, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# Cell In[3], line 8
#       6   p = pm.Uniform('p',0,1)
#       7   y = pm.Binomial('y', p = p, observed = y_values[i], n = n_values[i])
# ----> 8   trace = pm.sample(tune=2000)
#       9 print(i)
#      10 posterior = az.from_pymc3(trace)
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/sampling/mcmc.py:653, in sample(draws, tune, chains, cores, random_seed, progressbar, step, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, model, **kwargs)
#     650         auto_nuts_init = False
#     652 initial_points = None
# --> 653 step = assign_step_methods(model, step, methods=pm.STEP_METHODS, step_kwargs=kwargs)
#     655 if nuts_sampler != "pymc":
#     656     if not isinstance(step, NUTS):
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/sampling/mcmc.py:233, in assign_step_methods(model, step, methods, step_kwargs)
#     225         selected = max(
#     226             methods_list,
#     227             key=lambda method, var=rv_var, has_gradient=has_gradient: method._competence(  # type: ignore
#     228                 var, has_gradient
#     229             ),
#     230         )
#     231         selected_steps.setdefault(selected, []).append(var)
# --> 233 return instantiate_steppers(model, steps, selected_steps, step_kwargs)
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/sampling/mcmc.py:134, in instantiate_steppers(model, steps, selected_steps, step_kwargs)
#     132         args = step_kwargs.get(name, {})
#     133         used_keys.add(name)
# --> 134         step = step_class(vars=vars, model=model, **args)
#     135         steps.append(step)
#     137 unused_args = set(step_kwargs).difference(used_keys)
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/step_methods/hmc/nuts.py:180, in NUTS.__init__(self, vars, max_treedepth, early_max_treedepth, **kwargs)
#     122 def __init__(self, vars=None, max_treedepth=10, early_max_treedepth=8, **kwargs):
#     123     r"""Set up the No-U-Turn sampler.
#     124
#     125     Parameters
#    (...)
#     178     `pm.sample` to the desired number of tuning steps.
#     179     """
# --> 180     super().__init__(vars, **kwargs)
#     182     self.max_treedepth = max_treedepth
#     183     self.early_max_treedepth = early_max_treedepth
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/step_methods/hmc/base_hmc.py:109, in BaseHMC.__init__(self, vars, scaling, step_scale, is_cov, model, blocked, potential, dtype, Emax, target_accept, gamma, k, t0, adapt_step_size, step_rand, **pytensor_kwargs)
#     107 else:
#     108     vars = get_value_vars_from_user_vars(vars, self._model)
# --> 109 super().__init__(vars, blocked=blocked, model=self._model, dtype=dtype, **pytensor_kwargs)
#     111 self.adapt_step_size = adapt_step_size
#     112 self.Emax = Emax
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/step_methods/arraystep.py:164, in GradientSharedStep.__init__(self, vars, model, blocked, dtype, logp_dlogp_func, **pytensor_kwargs)
#     161 model = modelcontext(model)
#     163 if logp_dlogp_func is None:
# --> 164     func = model.logp_dlogp_function(vars, dtype=dtype, **pytensor_kwargs)
#     165 else:
#     166     func = logp_dlogp_func
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/model.py:600, in Model.logp_dlogp_function(self, grad_vars, tempered, **kwargs)
#     597     costs = [self.logp()]
#     599 input_vars = {i for i in graph_inputs(costs) if not isinstance(i, Constant)}
# --> 600 ip = self.initial_point(0)
#     601 extra_vars_and_values = {
#     602     var: ip[var.name]
#     603     for var in self.value_vars
#     604     if var in input_vars and var not in grad_vars
#     605 }
#     606 return ValueGradFunction(costs, grad_vars, extra_vars_and_values, **kwargs)
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/model.py:1085, in Model.initial_point(self, random_seed)
#    1072 def initial_point(self, random_seed: SeedSequenceSeed = None) -> Dict[str, np.ndarray]:
#    1073     """Computes the initial point of the model.
#    1074
#    1075     Parameters
#    (...)
#    1083         Maps names of transformed variables to numeric initial values in the transformed space.
#    1084     """
# -> 1085     fn = make_initial_point_fn(model=self, return_transformed=True)
#    1086     return Point(fn(random_seed), model=self)
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/initial_point.py:152, in make_initial_point_fn(model, overrides, jitter_rvs, default_strategy, return_transformed)
#     149 # Replace original rng shared variables so that we don't mess with them
#     150 # when calling the final seeded function
#     151 initial_values = replace_rng_nodes(initial_values)
# --> 152 func = compile_pymc(inputs=[], outputs=initial_values, mode=pytensor.compile.mode.FAST_COMPILE)
#     154 varnames = []
#     155 for var in model.free_RVs:
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pymc/pytensorf.py:1196, in compile_pymc(inputs, outputs, random_seed, mode, **kwargs)
#    1194 opt_qry = mode.provided_optimizer.including("random_make_inplace", check_parameter_opt)
#    1195 mode = Mode(linker=mode.linker, optimizer=opt_qry)
# -> 1196 pytensor_function = pytensor.function(
#    1197     inputs,
#    1198     outputs,
#    1199     updates={**rng_updates, **kwargs.pop("updates", {})},
#    1200     mode=mode,
#    1201     **kwargs,
#    1202 )
#    1203 return pytensor_function
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/compile/function/__init__.py:315, in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     309     fn = orig_function(
#     310         inputs, outputs, mode=mode, accept_inplace=accept_inplace, name=name
#     311     )
#     312 else:
#     313     # note: pfunc will also call orig_function -- orig_function is
#     314     #      a choke point that all compilation must pass through
# --> 315     fn = pfunc(
#     316         params=inputs,
#     317         outputs=outputs,
#     318         mode=mode,
#     319         updates=updates,
#     320         givens=givens,
#     321         no_default_updates=no_default_updates,
#     322         accept_inplace=accept_inplace,
#     323         name=name,
#     324         rebuild_strict=rebuild_strict,
#     325         allow_input_downcast=allow_input_downcast,
#     326         on_unused_input=on_unused_input,
#     327         profile=profile,
#     328         output_keys=output_keys,
#     329     )
#     330 return fn
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/compile/function/pfunc.py:367, in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys, fgraph)
#     353     profile = ProfileStats(message=profile)
#     355 inputs, cloned_outputs = construct_pfunc_ins_and_outs(
#     356     params,
#     357     outputs,
#    (...)
#     364     fgraph=fgraph,
#     365 )
# --> 367 return orig_function(
#     368     inputs,
#     369     cloned_outputs,
#     370     mode,
#     371     accept_inplace=accept_inplace,
#     372     name=name,
#     373     profile=profile,
#     374     on_unused_input=on_unused_input,
#     375     output_keys=output_keys,
#     376     fgraph=fgraph,
#     377 )
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/compile/function/types.py:1756, in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys, fgraph)
#    1744     m = Maker(
#    1745         inputs,
#    1746         outputs,
#    (...)
#    1753         fgraph=fgraph,
#    1754     )
#    1755     with config.change_flags(compute_test_value="off"):
# -> 1756         fn = m.create(defaults)
#    1757 finally:
#    1758     t2 = time.perf_counter()
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/compile/function/types.py:1649, in FunctionMaker.create(self, input_storage, storage_map)
#    1646 start_import_time = pytensor.link.c.cmodule.import_time
#    1648 with config.change_flags(traceback__limit=config.traceback__compile_limit):
# -> 1649     _fn, _i, _o = self.linker.make_thunk(
#    1650         input_storage=input_storage_lists, storage_map=storage_map
#    1651     )
#    1653 end_linker = time.perf_counter()
#    1655 linker_time = end_linker - start_linker
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/basic.py:254, in LocalLinker.make_thunk(self, input_storage, output_storage, storage_map, **kwargs)
#     247 def make_thunk(
#     248     self,
#     249     input_storage: Optional["InputStorageType"] = None,
#    (...)
#     252     **kwargs,
#     253 ) -> Tuple["BasicThunkType", "InputStorageType", "OutputStorageType"]:
# --> 254     return self.make_all(
#     255         input_storage=input_storage,
#     256         output_storage=output_storage,
#     257         storage_map=storage_map,
#     258     )[:3]
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/vm.py:1297, in VMLinker.make_all(self, profiler, input_storage, output_storage, storage_map)
#    1294 else:
#    1295     post_thunk_clear = None
# -> 1297 vm = self.make_vm(
#    1298     order,
#    1299     thunks,
#    1300     input_storage,
#    1301     output_storage,
#    1302     storage_map,
#    1303     post_thunk_clear,
#    1304     computed,
#    1305     compute_map,
#    1306     self.updated_vars,
#    1307 )
#    1309 vm.storage_map = storage_map
#    1310 vm.compute_map = compute_map
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/vm.py:1020, in VMLinker.make_vm(self, nodes, thunks, input_storage, output_storage, storage_map, post_thunk_clear, computed, compute_map, updated_vars)
#    1017 pre_call_clear = [storage_map[v] for v in self.no_recycling]
#    1019 try:
# -> 1020     from pytensor.link.c.cvm import CVM
#    1021 except (MissingGXX, ImportError):
#    1022     CVM = None
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cvm.py:13
#       9 if not config.cxx:
#      10     raise MissingGXX(
#      11         "lazylinker will not be imported if pytensor.config.cxx is not set."
#      12     )
# ---> 13 from pytensor.link.c.lazylinker_c import CLazyLinker
#      15 class CVM(CLazyLinker, VM):
#      16     def __init__(self, fgraph, *args, **kwargs):
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/lazylinker_c.py:143
#     140         assert os.path.exists(loc)
#     142 args = GCC_compiler.compile_args()
# --> 143 GCC_compiler.compile_str(dirname, code, location=loc, preargs=args)
#     144 # Save version into the __init__.py file.
#     145 init_py = os.path.join(loc, "__init__.py")
#
# File ~/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/cmodule.py:2649, in GCC_compiler.compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2641                 print(
#    2642                     "Check if package python-dev or python-devel is installed."
#    2643                 )
#    2645     # We replace '\n' by '. ' in the error message because when Python
#    2646     # prints the exception, having '\n' in the text makes it more
#    2647     # difficult to read.
#    2648     # compile_stderr = compile_stderr.replace("\n", ". ")
# -> 2649     raise CompileError(
#    2650         f"Compilation failed (return status={status}):\n{' '.join(cmd)}\n{compile_stderr}"
#    2651     )
#    2652 elif config.cmodule__compilation_warning and compile_stderr:
#    2653     # Print errors just below the command line.
#    2654     print(compile_stderr)
#
# CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver2 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver2 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/numpy/core/include -I/home/nrobledo/.pyenv/versions/3.11.0/include/python3.11 -I/home/nrobledo/.pyenv/versions/testing/lib/python3.11/site-packages/pytensor/link/c/c_code -L/home/nrobledo/.pyenv/versions/3.11.0/lib -fvisibility=hidden -o /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/lazylinker_ext/lazylinker_ext.so /home/nrobledo/.pytensor/compiledir_Linux-5.15-microsoft-standard-WSL2-x86_64-with-glibc2.35-x86_64-3.11.0-64/lazylinker_ext/mod.cpp -lpython3.11
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(dictobject.o): warning: relocation against `PyDictKeys_Type' in read-only section `.text'
# /usr/bin/ld: /home/nrobledo/.pyenv/versions/3.11.0/lib/libpython3.11.a(bytearrayobject.o): relocation R_X86_64_PC32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC
# /usr/bin/ld: final link failed: bad value
# collect2: error: ld returned 1 exit status
